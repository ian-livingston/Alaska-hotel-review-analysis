# %%
import pandas as pd
import numpy as np
import pickle
from corextopic import corextopic as ct
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, ENGLISH_STOP_WORDS
from tqdm import tqdm
from nltk import word_tokenize, FreqDist
import matplotlib.pyplot as plt
import spacy
import time, os
from Functions import top_words

# %%
with open("newest_main_df.pickle", "rb") as to_read:
    main_df = pickle.load(to_read)

# %%
# !pip install corextopic
# !pip install networkx
from corextopic import corextopic as ct

# %%
import pandas as pd
import numpy as np
import scipy.sparse as ss

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn import datasets

from corextopic import corextopic as ct
from corextopic import vis_topic as vt

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
corex_df = pd.DataFrame(columns=["Topics", "Anchors", "Topic words", "TC", "TCs", "Labels", "Clusters", "Alpha", "Mis", "P(y)|x", "Words", "N-gram range", "min_df", "max_df"])
corex_df
# Out:
# Empty DataFrame
# Columns: [Topics, Anchors, Topic words, TC, TCs, Labels, Clusters, Alpha, Mis, P(y)|x, Words, N-gram range, min_df, max_df]
# Index: []

# %%
corpus = main_df["Clean review no cities"]
vectorizer = TfidfVectorizer(max_df=.5,
    min_df=5,
    max_features=None,
    ngram_range=(1, 2),
    norm=None,
    binary=True,
    use_idf=False,
    sublinear_tf=False)
vectorizer = vectorizer.fit(corpus)
tfidf = vectorizer.transform(corpus)
words = list(np.asarray(vectorizer.get_feature_names()))

# %%
for i in tqdm(range(25, 28)):
    topic_model = ct.Corex(n_hidden=i, words=words, seed=10)
    topic_model.fit(tfidf, words=words, docs=corpus, anchors=[["hotel", "lodge"], ["aurora", "northern lights"]])

    topic_words = []
    for x, topic_ngrams in enumerate(topic_model.get_topics(n_words=10)):
        topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
        topic_words.append("Topic #{}: {}".format(x+1, ", ".join(topic_ngrams)))

    corex_details = {"Topics": i, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"]], "Topic words": topic_words, "TC": topic_model.tc, "TCs": topic_model.tcs, "Labels": topic_model.labels, "Clusters": topic_model.clusters, "Alpha": topic_model.alpha, "Mis": topic_model.mis, "P(y)|x": topic_model.p_y_given_x, "Words": topic_model.words, "N-gram range": (1, 2), "min_df": 5, "max_df": 0.5}

    corex_df = corex_df.append(corex_details, ignore_index=True)
    corex_df
# Out:
# 100%|██████████| 3/3 [33:47<00:00, 675.96s/it]

# %%
for i in tqdm(range(6, 10)):
    topic_model = ct.Corex(n_hidden=i, words=words, seed=10)
    topic_model.fit(tfidf, words=words, docs=corpus, anchors=[["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"], ["downtown"], ["staff", "service", "reception"]])

    topic_words = []
    for x, topic_ngrams in enumerate(topic_model.get_topics(n_words=10)):
        topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
        topic_words.append("Topic #{}: {}".format(x+1, ", ".join(topic_ngrams)))

    corex_details = {"Topics": i, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"], ["downtown"], ["staff", "service", "reception"]], "Topic words": topic_words, "TC": topic_model.tc, "TCs": topic_model.tcs, "Labels": topic_model.labels, "Clusters": topic_model.clusters, "Alpha": topic_model.alpha, "Mis": topic_model.mis, "P(y)|x": topic_model.p_y_given_x, "Words": topic_model.words, "N-gram range": (1, 2), "min_df": 5, "max_df": 0.5}

    corex_df = corex_df.append(corex_details, ignore_index=True)
    corex_df
# Out:
# 100%|██████████| 4/4 [21:18<00:00, 319.53s/it]

# %%
for i in tqdm(range(10, 14)):
    topic_model = ct.Corex(n_hidden=i, words=words, seed=10)
    topic_model.fit(tfidf, words=words, docs=corpus, anchors=[["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"], ["downtown"], ["staff", "service", "reception"]])

    topic_words = []
    for x, topic_ngrams in enumerate(topic_model.get_topics(n_words=10)):
        topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
        topic_words.append("Topic #{}: {}".format(x+1, ", ".join(topic_ngrams)))

    corex_details = {"Topics": i, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"], ["downtown"], ["staff", "service", "reception"]], "Topic words": topic_words, "TC": topic_model.tc, "TCs": topic_model.tcs, "Labels": topic_model.labels, "Clusters": topic_model.clusters, "Alpha": topic_model.alpha, "Mis": topic_model.mis, "P(y)|x": topic_model.p_y_given_x, "Words": topic_model.words, "N-gram range": (1, 2), "min_df": 5, "max_df": 0.5}

    corex_df = corex_df.append(corex_details, ignore_index=True)
    corex_df
# Out:
# 100%|██████████| 4/4 [24:42<00:00, 370.56s/it]

# %%
for i in tqdm(range(2, 4)):
    topic_model = ct.Corex(n_hidden=i, words=words, seed=10)
    topic_model.fit(tfidf, words=words, docs=corpus, anchors=[["love", "beautiful"]], anchor_strength=5)

    topic_words = []
    for x, topic_ngrams in enumerate(topic_model.get_topics(n_words=10)):
        topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
        topic_words.append("Topic #{}: {}".format(x+1, ", ".join(topic_ngrams)))

    corex_details = {"Topics": i, "Anchors": [["love", "beautiful"]], "Topic words": topic_words, "TC": topic_model.tc, "TCs": topic_model.tcs, "Labels": topic_model.labels, "Clusters": topic_model.clusters, "Alpha": topic_model.alpha, "Mis": topic_model.mis, "P(y)|x": topic_model.p_y_given_x, "Words": topic_model.words, "N-gram range": (1, 2), "min_df": 5, "max_df": 0.5}

    corex_df = corex_df.append(corex_details, ignore_index=True)
    corex_df
# Out:
# 100%|██████████| 2/2 [07:43<00:00, 231.91s/it]

# %%
for i in tqdm(range(3, 8)):
    topic_model = ct.Corex(n_hidden=i, words=words, seed=10)
    topic_model.fit(tfidf, words=words, docs=corpus, anchors=[["love", "beautiful", "perfect", "wonderful"], ["hate", "disgusting"]], anchor_strength=5)

    topic_words = []
    for x, topic_ngrams in enumerate(topic_model.get_topics(n_words=10)):
        topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
        topic_words.append("Topic #{}: {}".format(x+1, ", ".join(topic_ngrams)))

    corex_details = {"Topics": i, "Anchors": [["love", "beautiful", "perfect", "wonderful"], ["hate", "disgusting"]], "Topic words": topic_words, "TC": topic_model.tc, "TCs": topic_model.tcs, "Labels": topic_model.labels, "Clusters": topic_model.clusters, "Alpha": topic_model.alpha, "Mis": topic_model.mis, "P(y)|x": topic_model.p_y_given_x, "Words": topic_model.words, "N-gram range": (1, 2), "min_df": 5, "max_df": 0.5}

    corex_df = corex_df.append(corex_details, ignore_index=True)
    corex_df
# Out:
# 100%|██████████| 5/5 [22:37<00:00, 271.46s/it]

# %%
for i in tqdm(range(2, 5)):
    topic_model = ct.Corex(n_hidden=i, words=words, seed=10)
    topic_model.fit(tfidf, words=words, docs=corpus, anchors=[["weather", "cold", "freezing"], ["dark", "light"]], anchor_strength=5)

    topic_words = []
    for x, topic_ngrams in enumerate(topic_model.get_topics(n_words=10)):
        topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
        topic_words.append("Topic #{}: {}".format(x+1, ", ".join(topic_ngrams)))

    corex_details = {"Topics": i, "Anchors": [["weather", "cold", "freezing"], ["dark", "light"]], "Topic words": topic_words, "TC": topic_model.tc, "TCs": topic_model.tcs, "Labels": topic_model.labels, "Clusters": topic_model.clusters, "Alpha": topic_model.alpha, "Mis": topic_model.mis, "P(y)|x": topic_model.p_y_given_x, "Words": topic_model.words, "N-gram range": (1, 2), "min_df": 5, "max_df": 0.5}

    corex_df = corex_df.append(corex_details, ignore_index=True)
    corex_df
# Out:
# 100%|██████████| 3/3 [09:08<00:00, 182.93s/it]

# %%
with open("corex_df.pickle", "wb") as to_write:
     pickle.dump(corex_df, to_write)

# %%
corex_df
# Out:
# ts]]
# 4       7        [[hotel, lodge], [aurora, northern lights]]
# 5       8        [[hotel, lodge], [aurora, northern lights]]
# 6       9        [[hotel, lodge], [aurora, northern lights]]
# 7      10        [[hotel, lodge], [aurora, northern lights]]
# 8      11        [[hotel, lodge], [aurora, northern lights]]
# 9      12        [[hotel, lodge], [aurora, northern lights]]
# 10     13        [[hotel, lodge], [aurora, northern lights]]
# 11     14        [[hotel, lodge], [aurora, northern lights]]
# 12     15        [[hotel, lodge], [aurora, northern lights]]
# 13     16        [[hotel, lodge], [aurora, northern lights]]
# 14     17        [[hotel, lodge], [aurora, northern lights]]
# 15     18        [[hotel, lodge], [aurora, northern lights]]
# 16     19        [[hotel, lodge], [aurora, northern lights]]
# 17     20        [[hotel, lodge], [aurora, northern lights]]
# 18     21        [[hotel, lodge], [aurora, northern lights]]
# ...

# %%
topic_words = []
for x, topic_ngrams in enumerate(topic_model.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    topic_words.append("Topic #{}: {}".format(x+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 9, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"]], "Topic words": topic_words, "TC": topic_model.tc, "TCs": topic_model.tcs, "Labels": topic_model.labels, "Clusters": topic_model.clusters, "Alpha": topic_model.alpha, "Mis": topic_model.mis, "P(y)|x": topic_model.p_y_given_x, "Words": topic_model.words, "N-gram range": (1, 2), "min_df": 5, "max_df": 0.5}

corex_df = corex_df.append(corex_details, ignore_index=True)
corex_df
# Out:
#   Topics                                      Anchors  \
# 0      3  [[hotel, lodge], [aurora, northern lights]]
# 1      4  [[hotel, lodge], [aurora, northern lights]]
# 2      5  [[hotel, lodge], [aurora, northern lights]]
# 3      6  [[hotel, lodge], [aurora, northern lights]]
# 4      7  [[hotel, lodge], [aurora, northern lights]]
# 5      8  [[hotel, lodge], [aurora, northern lights]]
# 6      9  [[hotel, lodge], [aurora, northern lights]]
#
#                                          Topic words         TC  \
# 0  [Topic #1: hotel, shuttle, desk, staff, restau...  11.934996
# 1  [Topic #1: hotel, shuttle, desk, restaurant, l...  13.058124
# 2  [Topic #1: hotel, shuttle, desk, staff, restau...  14.800884
# 3  [Topic #1: hotel, shuttle, restaurant, airport...  15.342013
# 4  [Topic #1: hotel, staff, desk, shuttle, lobby,...  16.172156
# 5  [Topic #1: hotel, shuttle, desk, staff, lobby,...  17.223123
# 6  [Topic #1: hotel, shuttle, desk, staff, restau...  17.139097
#
# ...

# %%
corex_df
# Out:
#    Topics                                      Anchors  \
# 0       3  [[hotel, lodge], [aurora, northern lights]]
# 1       4  [[hotel, lodge], [aurora, northern lights]]
# 2       5  [[hotel, lodge], [aurora, northern lights]]
# 3       6  [[hotel, lodge], [aurora, northern lights]]
# 4       7  [[hotel, lodge], [aurora, northern lights]]
# 5       8  [[hotel, lodge], [aurora, northern lights]]
# 6       9  [[hotel, lodge], [aurora, northern lights]]
# 7      10  [[hotel, lodge], [aurora, northern lights]]
# 8      11  [[hotel, lodge], [aurora, northern lights]]
# 9      12  [[hotel, lodge], [aurora, northern lights]]
# 10     13  [[hotel, lodge], [aurora, northern lights]]
# 11     14  [[hotel, lodge], [aurora, northern lights]]
# 12     15  [[hotel, lodge], [aurora, northern lights]]
# 13     16  [[hotel, lodge], [aurora, northern lights]]
# 14     17  [[hotel, lodge], [aurora, northern lights]]
# 15     18  [[hotel, lodge], [aurora, northern lights]]
# ...

# %%
for i, topic_ngrams in enumerate(topic_model.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))
# Out:
# Topic #1: hotel, shuttle, desk, airport, stay hotel, hotel room, shuttle service, lobby, free shuttle
# Topic #2: fishing, fish, guide, salmon, catch, trip, halibut, boat, bear, fishing trip
# Topic #3: enjoy, cozy, relax, enjoy stay, really enjoy, appoint, beach, atmosphere, ocean, thoroughly
# Topic #4: night, stay night, spend night, night stay, night room, night sleep, northern light, northern, room night, good night
# Topic #5: people, review, think, expect, want, question, read, star, answer, yes
# Topic #6: food, dinner, meal, eat, lunch, food good, good food, menu, great food, drink
# Topic #7: floor, window, smell, carpet, wall, open, door, noise, dirty, fan
# Topic #8: cabin, cabin clean, stay cabin, decorate, porch, log, creek, loft, log cabin, wood
# Topic #9: denali, park, national, national park, denali national, rv park, denali park, entrance, park entrance, stay denali
# Topic #10: price, free, wifi, parking, car, internet, basic, reasonable, parking lot, pay
# ...

# %%
topic_model.get_top_docs(topic=0, n_docs=10)
# Out:
# [('check love property gorgeous andi dave perfect host lot sweet touch like lemonade cookie arrival wait return ',
#   0.0),
#  ('stay stephen juxia night midseason clearly love  wealth information share juxia arrange amazing kayak trip cook special meal early stephen wealth story warmly room unpretentious really feel home space perfectly clean quiet night nice touch like shower bed reliable wifi awesome food coffee edible plant ground provide great snack enjoy view wait ',
#   0.0),
#  ('lovely room beautiful view breakfast fine juxia great hostess cheerful helpful pleasant host bit downer weird rule coffee hot tub make guest d wholeheartedly know interaction guest limited ',
#   0.0),
# ...

# %%
top_words(main_df, 100, column="Review nouns")
# Out:
# 1. ('room', 95543)
# 2. ('hotel', 49726)
# 3. ('breakfast', 34762)
# 4. ('night', 33960)
# 5. ('place', 33919)
# 6. ('staff', 32240)
# 7. ('bed', 23899)
# 8. ('day', 23084)
# 9. ('cabin', 21906)
# 10. ('lodge', 21795)
# 11. ('time', 21539)
# 12. ('view', 21281)
# 13. ('stay', 20292)
# 14. ('restaurant', 19124)
# 15. ('alaska', 18968)
# 16. ('area', 18557)
# 17. ('location', 17333)
# 18. ('trip', 15734)
# 19. ('food', 15061)
# 20. ('service', 13919)
# 21. ('bathroom', 11777)
# 22. ('walk', 11775)
# 23. ('town', 10934)
# 24. ('experience', 10819)
# 25. ('shuttle', 10697)
# 26. ('park', 10664)
# 27. ('lot', 10283)
# 28. ('desk', 10127)
# 29. ('clean', 10030)
# 30. ('people', 9665)
# 31. ('airport', 9278)
# 32. ('book', 9256)
# 33. ('anchorage', 9137)
# 34. ('family', 9123)
# 35. ('denali', 8936)
# 36. ('way', 8838)
# 37. ('morning', 8802)
# 38. ('tour', 8735)
# 39. ('downtown', 8642)
# 40. ('price', 8620)
# 41. ('fishing', 8485)
# 42. ('coffee', 8381)
# 43. ('didst', 8330)
# ...

# %%
top_words(main_df, 100, column="Review adjs")
# Out:
# 1. ('great', 36210)
# 2. ('good', 33449)
# 3. ('clean', 25159)
# 4. ('nice', 22494)
# 5. ('friendly', 17838)
# 6. ('helpful', 13360)
# 7. ('small', 12798)
# 8. ('beautiful', 11592)
# 9. ('little', 9429)
# 10. ('wonderful', 8988)
# 11. ('large', 8951)
# 12. ('close', 8713)
# 13. ('hot', 7171)
# 14. ('free', 6920)
# 15. ('quiet', 6775)
# 16. ('old', 6575)
# 17. ('amazing', 6523)
# 18. ('perfect', 5761)
# 19. ('available', 5640)
# 20. ('main', 5338)
# 21. ('excellent', 5289)
# 22. ('right', 5233)
# 23. ('spacious', 5198)
# 24. ('open', 5138)
# 25. ('new', 4750)
# 26. ('long', 4670)
# 27. ('big', 4556)
# 28. ('able', 4480)
# 29. ('early', 4320)
# 30. ('bad', 4301)
# 31. ('sure', 4292)
# 32. ('convenient', 4023)
# 33. ('local', 3816)
# 34. ('easy', 3792)
# 35. ('fantastic', 3600)
# 36. ('warm', 3596)
# 37. ('second', 3584)
# 38. ('late', 3503)
# 39. ('short', 3491)
# 40. ('high', 3339)
# 41. ('alaskan', 3310)
# 42. ('private', 3232)
# 43. ('pleasant', 3170)
# 44. ('different', 3159)
# ...

# %%
top_adjs_by_month = {}
for month in tqdm(range(1, 13)):

    top_words = []
    corpus = list(main_df[main_df["Month of stay"] == month]["Review adjs"])
    one_big_string = " ".join(corpus)
    splits = one_big_string.split()
    freq_splits = FreqDist(splits)
    for i, term in enumerate(freq_splits.most_common(50)):
        top_words.append(f'{i+1}. {term}')
    
    top_adjs_by_month[f'Month {month}'] = top_words
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 19.92it/s]

# %%
def third_clean(review):

    cleaned_review = []
    stop_words = ["didst", "ovid", "thing", "place", "use", "alaska"]

    for token in review.split(" "):
        if token not in stop_words:
            cleaned_review.append(token)

    return " ".join(cleaned_review)

# %%
top_adjs_by_month
with open("adjs_by_month.pickle", "wb") as to_write:
    pickle.dump(top_adjs_by_month, to_write)

# %%
# main_df["Cleaned review v3"] = main_df["Cleaned review v2"].apply(lambda x: third_clean(x))

# %%
def city_clean(review):

    for city in cities:
        if city in review:
            review = "".join(review.split(city))
    
    return review

# %%
# main_df["Clean review no cities"] = main_df["Cleaned review v3"].apply(lambda x: city_clean(x))

# %%
cities = []
for address in tqdm(list(main_df["Property address"].unique())):
    try:
        cities.append(address.split(', ')[1])
    except AttributeError:
        continue
cities = [city for city in cities if cities.count(city) > 15]
cities = list(set(cities))
cities = [city.lower() for city in cities]
cities.remove("king salmon")
# Out:
# 100%|██████████| 1371/1371 [00:00<00:00, 533678.96it/s]

# %%
with open("newest_main_df.pickle", "wb") as to_write:
     pickle.dump(main_df, to_write)
