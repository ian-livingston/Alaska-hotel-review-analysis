# %%
import pandas as pd
import numpy as np
import pickle
import re
from sklearn.decomposition import TruncatedSVD, NMF
from nltk.corpus import stopwords
from corextopic import corextopic as ct
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, ENGLISH_STOP_WORDS
import nltk
from tqdm import tqdm
from nltk import word_tokenize, FreqDist
import matplotlib.pyplot as plt
import pkg_resources
from symspellpy import SymSpell, Verbosity
import spacy
import datetime as dt
import time, os

# %%
with open("newest_main_df.pickle", "rb") as to_read:
    main_df = pickle.load(to_read)

# %% [markdown]
# ## Dropping NaNs in "Full review" and spell-checking all words longer than five letters
#  - 111529 -> 94513 NaNs (possible that other kinds of cleaning/filtering helpef before all_hotels_df was unpickled here, however)
# - 94295 reviews were changed by SymSpell spell-check function and 218 were not
#     - worth noting that periods and spaces were updated so not all included actual typos or spelling errors

# %%
#main_df = spell_checker(all_hotels_df, pickling=True)
# Out:
# 100%|██████████| 94513/94513 [01:45<00:00, 899.77it/s]

# %% [markdown]
# ## Cleaning spell-checked reviews
# Took 17 minutes to run!

# %%
# main_df = review_cleaner(main_df)
# Out:
# 100%|██████████| 94513/94513 [17:09<00:00, 91.79it/s]

# %% [markdown]
# ## Adding a month column from "Date of stay"

# %%
# main_df["Month of stay"] = pd.DatetimeIndex(main_df["Date of stay"]).month
# main_df["Year of stay"] = pd.DatetimeIndex(main_df["Date of stay"]).year

# %%
# main_df["Month of stay"].value_counts()
# Out:
# 7.0     22284
# 8.0     20829
# 6.0     19069
# 9.0      9875
# 5.0      7889
# 3.0      2819
# 10.0     2420
# 4.0      2021
# 2.0      2015
# 1.0      1555
# 11.0     1535
# 12.0     1517
# Name: Month of stay, dtype: int64

# %%
with open("all_alaska_hotels_spell_checked.pickle", "wb") as to_write:
     pickle.dump(main_df, to_write)

# %% [markdown]
# ## Checking top words
# - Sorted by month, they are all essentially and concern hotel matters
# - Ran LSA and NMF with 2 topics each and didn't get much
#     - In LSA, explained variance ratios were 0.0029 and 0.0075 respectively and both related to hotel matters

# %%
top_words(main_df, separater="Month of stay")
# Out:
# Most common words: 10.0:
# 1. ('room', 2385)
# 2. ('stay', 2180)
# 3. ('hotel', 1696)
# 4. ('great', 1075)
# 5. ('staff', 1057)
# 6. ('good', 1021)
# 7. ('clean', 1019)
# 8. ('breakfast', 914)
# 9. ('place', 849)
# 10. ('nice', 745)
#
# Most common words: 9.0:
# 1. ('room', 10119)
# 2. ('stay', 8302)
# 3. ('hotel', 5439)
# 4. ('great', 4307)
# 5. ('good', 4246)
# 6. ('clean', 3867)
# 7. ('night', 3683)
# 8. ('breakfast', 3478)
# 9. ('staff', 3447)
# 10. ('place', 3443)
#
# Most common words: 6.0:
# 1. ('room', 19387)
# 2. ('stay', 15908)
# 3. ('hotel', 9214)
# 4. ('great', 8210)
# 5. ('good', 7657)
# 6. ('clean', 7194)
# 7. ('night', 7131)
# 8. ('breakfast', 7116)
# 9. ('place', 7061)
# 10. ('one', 6202)
#
# Most common words: 7.0:
# 1. ('room', 21867)
# 2. ('stay', 18648)
# 3. ('hotel', 10437)
# 4. ('great', 9706)
# 5. ('good', 8903)
# 6. ('place', 8727)
# 7. ('clean', 8454)
# 8. ('night', 8219)
# 9. ('breakfast', 8047)
# 10. ('nice', 7136)
#
# Most common words: 8.0:
# 1. ('room', 20802)
# 2. ('stay', 16972)
# 3. ('hotel', 10108)
# 4. ('great', 9057)
# 5. ('good', 8542)
# 6. ('night', 8045)
# 7. ('place', 7986)
# 8. ('clean', 7943)
# 9. ('breakfast', 7639)
# 10. ('nice', 6694)
#
# Most common words: 5.0:
# 1. ('room', 8398)
# 2. ('stay', 6778)
# 3. ('hotel', 4624)
# 4. ('great', 3392)
# 5. ('good', 3177)
# 6. ('clean', 3137)
# 7. ('breakfast', 3030)
# 8. ('place', 2804)
# 9. ('staff', 2753)
# 10. ('night', 2686)
#
# Most common words: 3.0:
# 1. ('room', 2946)
# 2. ('stay', 2531)
# 3. ('hotel', 1839)
# 4. ('great', 1339)
# 5. ('staff', 1233)
# 6. ('clean', 1171)
# 7. ('good', 1111)
# 8. ('breakfast', 1105)
# 9. ('place', 1047)
# 10. ('nice', 910)
#
# Most common words: 1.0:
# 1. ('room', 1570)
# 2. ('stay', 1375)
# 3. ('hotel', 1030)
# 4. ('great', 739)
# 5. ('staff', 689)
# 6. ('clean', 601)
# 7. ('good', 593)
# 8. ('place', 545)
# 9. ('breakfast', 542)
# 10. ('nice', 499)
#
# Most common words: 2.0:
# 1. ('room', 2170)
# 2. ('stay', 1813)
# 3. ('hotel', 1462)
# 4. ('staff', 961)
# 5. ('great', 912)
# 6. ('breakfast', 808)
# 7. ('good', 790)
# 8. ('clean', 781)
# 9. ('nice', 682)
# 10. ('place', 653)
#
# Most common words: 12.0:
# 1. ('room', 1538)
# 2. ('stay', 1379)
# 3. ('hotel', 1058)
# 4. ('staff', 708)
# 5. ('great', 668)
# 6. ('breakfast', 594)
# 7. ('good', 576)
# 8. ('clean', 567)
# 9. ('place', 478)
# 10. ('nice', 467)
#
# Most common words: 11.0:
# 1. ('room', 1622)
# 2. ('stay', 1378)
# 3. ('hotel', 1032)
# 4. ('great', 697)
# 5. ('staff', 691)
# 6. ('good', 639)
# 7. ('clean', 601)
# 8. ('breakfast', 548)
# 9. ('place', 543)
# 10. ('nice', 485)
#
# Most common words: 4.0:
# 1. ('room', 2214)
# 2. ('stay', 1820)
# 3. ('hotel', 1313)
# 4. ('great', 921)
# 5. ('staff', 883)
# 6. ('clean', 858)
# 7. ('good', 810)
# 8. ('breakfast', 747)
# 9. ('place', 672)
# 10. ('nice', 595)

# %%
run_model(main_df, "lsa", 2)
# Out:
# Topic 1
# ['staff', 'nice', 'clean', 'good', 'great', 'hotel']
# Explained variance ratio: 0.0028742653671233478
#
# Topic 2
# ['anchorage', 'downtown', 'staff', 'shuttle', 'airport', 'hotel']
# Explained variance ratio: 0.007528947079170521

# %%
run_model(main_df, "nmf", 2)
# Out:
# Topic 1
# ['breakfast', 'nice', 'clean', 'good', 'staff', 'hotel']
#
# Topic 2
# ['make', 'view', 'place', 'lodge', 'great', 'cabin']

# %%
results_df = run_model(main_df, "nmf", 2, results_df=True)
# Out:
# Topic 1
# ['nice', 'clean', 'good', 'staff', 'hotel']
#
# Topic 2
# ['view', 'place', 'lodge', 'great', 'cabin']

# %%
results_df.sort_values(by=0, ascending=False)
# Out:
#               0         1                                        Full review  \
# 15745  0.084707  0.000000  We really enjoyed our stay at this hotel.  All...
# 93338  0.080808  0.000000  We stayed here, downtown, for 3 nights. There ...
# 14629  0.078912  0.000000  Although this hotel isn't located downtown, it...
# 2401   0.078685  0.000000  My husband and I have stayed here several time...
# 7778   0.075515  0.000000  This hotel is very convenient to the airport. ...
# ...         ...       ...                                                ...
# 11119  0.000000  0.039544  After all day driving and sightseeing, Larry w...
# 54754  0.000000  0.038839                                                NaN
# 11117  0.000000  0.037809  We stayed for two nights and found it to be on...
# 54752  0.000000  0.047527                                                NaN
# 24028  0.000000  0.034204  This home (Lupine) has everything you need and...
#
#                                           Cleaned review
# 15745  really enjoy stay hotel hotel staff nice room ...
# 93338  stay downtown night hotel shuttle ferry expect...
# 14629  although hotel be not locate downtown nice loc...
# 2401   husband stay several time seem like old hotel ...
# 7778   hotel convenient airport good shuttle service ...
# ...                                                  ...
# 11119  day drive sightseeing larry quick get check co...
# 54754                                                NaN
# 11117  stay two night find one good cabin stay kitche...
# 54752                                                NaN
# 24028  home lupine everything need give home star rat...
#
# [94513 rows x 4 columns]

# %%
results_df = run_model(main_df, "nmf", 5, results_df=True)
# Out:
# Topic 1
# ['shuttle', 'restaurant', 'good', 'staff', 'hotel']
#
# Topic 2
# ['wonderful', 'view', 'breakfast', 'place', 'great']
#
# Topic 3
# ['small', 'creek', 'park', 'denali', 'cabin']
#
# Topic 4
# ['day', 'trip', 'fish', 'fishing', 'lodge']
#
# Topic 5
# ['nice', 'small', 'bathroom', 'night', 'bed']

# %%
results_df.sort_values(by=2, ascending=False)
# Out:
#               0         1         2  \
# 65984  0.000000  0.000000  0.141851
# 60270  0.000000  0.000000  0.122540
# 40175  0.000000  0.000000  0.122437
# 64795  0.000000  0.000000  0.122111
# 40065  0.000000  0.000000  0.121195
# ...         ...       ...       ...
# 76420  0.025359  0.008739  0.000000
# 76419  0.029318  0.000000  0.000000
# 60890  0.040815  0.000000  0.000000
# 31566  0.033260  0.014950  0.000000
# 20763  0.039697  0.025205  0.000000
#
#                                              Full review  \
# 65984                                                NaN
# 60270                                                NaN
# 40175  We stayed at McKinley Creekside Cabins on 7-30...
# 64795                                                NaN
# 40065  Four adults stayed for two nights in the Carlo...
# ...                                                  ...
# 76420  Favorite stay of our 10-day Alaskan adventure....
# 76419  I did a lot of searching on TripAdvisor before...
# 60890                                                NaN
# 31566  Well located, clean and comfortable.  Good opt...
# 20763  I stayed at the Sheraton in Anchorage a couple...
#
#                                           Cleaned review
# 65984                                                NaN
# 60270                                                NaN
# 40175  stay mckinley creekside cabin cabin clean love...
# 64795                                                NaN
# 40065  four adult stay two night carlo cabin staff ex...
# ...                                                  ...
# 76420  favourite stay day alaskan adventure view bb s...
# 76419  lot search tripadvisor book bed breakfast even...
# 60890                                                NaN
# 31566  well locate clean good option fisherman overni...
# 20763  stay sheraton anchorage couple time summer tra...
#
# [94513 rows x 5 columns]

# %% [markdown]
# ## Trying Vader

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
main_df = vader_scores(main_df)
# Out:
# 100%|██████████| 94513/94513 [00:43<00:00, 2187.31it/s]

# %%
main_df.groupby("Month of stay")["Vader +"].mean()
# Out:
# Month of stay
# 1.0     0.333032
# 2.0     0.329967
# 3.0     0.326659
# 4.0     0.333819
# 5.0     0.314747
# 6.0     0.307647
# 7.0     0.306632
# 8.0     0.304542
# 9.0     0.312721
# 10.0    0.333707
# 11.0    0.332612
# 12.0    0.332488
# Name: Vader +, dtype: float64

# %%
main_df.groupby("Month of stay")["Vader -"].mean()
# Out:
# Month of stay
# 1.0     0.043122
# 2.0     0.040432
# 3.0     0.041645
# 4.0     0.041874
# 5.0     0.040397
# 6.0     0.042529
# 7.0     0.042481
# 8.0     0.043819
# 9.0     0.041674
# 10.0    0.041539
# 11.0    0.042252
# 12.0    0.040735
# Name: Vader -, dtype: float64

# %% [markdown]
# ## Trying to get hotel rates

# %%
with open("hotel_urls.pickle", "rb") as to_read:
    hotel_urls = pickle.load(to_read)

# %%
def get_hotel_rates(list_of_urls):
    '''Takes a list of URLs and grabs the rate for each, returning it as the value to the
    property name key.
    '''
    rate_dict = {}

    chromedriver = "/Applications/chromedriver"
    os.environ["webdriver.chrome.driver"] = chromedriver
    driver = webdriver.Chrome(chromedriver)
    driver.get("https://www.tripadvisor.com/Hotels-g28923-Alaska-Hotels.html")
    hotels_toggle = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div/div[1]/div[1]/div[5]/div/div/div[2]/div[2]/div[2]/div[4]/div/label')
    hotels_toggle.click()
    for i in range(99):
        print(i)
        time.sleep(7)
        soup = BeautifulSoup(driver.page_source)
        listings = soup.find("div", id="taplc_hsx_hotel_list_lite_dusty_hotels_combined_sponsored_0").find_all("div", class_="prw_rup prw_meta_hsx_responsive_listing ui_section listItem")
        for listing in listings:
            property = listing.find("div", class_="listing_title").text
            print(property)
            try:
                rate = int("".join(listing.find("div", class_="price-wrap").text.split("$")[1].split(",")))
            except AttributeError:
                rate = np.NaN
            rate_dict[property] = rate
        next_button = driver.find_element_by_xpath('//*[@id="taplc_main_pagination_bar_dusty_hotels_resp_0"]/div/div/div/span[2]')
        next_button.click()
        with open("hotel_rates.pickle", "wb") as to_write:
            pickle.dump(rate_dict, to_write)

    return rate_dict

# %%
rate_dict = get_hotel_rates(hotel_urls)
# Out:
# 0
#       Harbor 360 Hotel
#       Alyeska Resort
#       Pike's Waterfront Lodge
#       Aurora Denali Lodge
#       The Hotel Captain Cook
#       Denali Lakeview Inn
#       Land's End Resort
#       The Lakefront Anchorage
#       Embassy Suites by Hilton Anchorage
#       Chena Hot Springs Resort
#       Denali Fireside Cabins & Suites
#       La Quinta Inn & Suites by Wyndham Anchorage Airport
#       La Quinta Inn & Suites by Wyndham Fairbanks Airport
#       SpringHill Suites by Marriott Fairbanks
#       Best Western Golden Lion Hotel
#       The Voyager Inn
#       Wedgewood Resort
#       Best Western Grandma'S Feather Bed
#       Turnagain View Lodge
#       Kingfisher Charters & Lodge
#       Arctic Getaway Bed and Breakfast
#       Dredge No.7 Inn
#       Salmon Creek Cabins
#       House on the Rock B & B
#       All Alaska Outdoors Lodge
#       Healy Heights Family Cabins
#       The Aurora Express
#       Fox 'n Fireweed
#       Salted Roots Cabins
#       Annie Mae Lodge
#       Denali Park Hotel
#       Stillpoint Lodge
#       Zachar Bay Lodge
#       Mt. McKinley Princess Wilderness Lodge
#       Waterfall Resort Alaska
#       Bent Prop Inn & Hostel Downtown
# 14
#       Orca Lodge
#       Log Cabin Wilderness Lodge
#       A Room with a View Bed and Breakfast
#       House of Seven Trees
#       Alaska Rainbow Lodge
#       Latitude71 B and B
#       Heritage RV Park
#       Kenai Riverside Lodge
#       The Farm Lodge
#       Cliffhanger B and B
#       Jorgenson House Bed and Breakfast
#       Talkeetna Camper Park
#       Intricate Bay Lodge
#       Brooks Camp
#       ah Rose Marie Bed and Breakfast
#       Camelot Cottages
#       Riley Creek
#       Grande Denali Lodge
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-1693a3ee8fe7> in <module>
# ----> 1 rate_dict = get_hotel_rates(hotel_urls)
#
# <ipython-input-35-305215516ac0> in get_hotel_rates(list_of_urls)
#      20             print(property)
#      21             try:
# ---> 22                 rate = int("".join(listing.find("div", class_="price-wrap").text.split("$")[1].split(",")))
#      23             except AttributeError:
#      24                 rate = np.NaN
#
# IndexError: list index out of range

# %%
with open("hotel_rates.pickle", "rb") as to_read:
    rates_dict = pickle.load(to_read)

# %% [markdown]
# ## Inputting lats and longs as floats

# %%
for_mapping_df = main_df[main_df["Lat, long"].notna()]
lats = []
longs = []
for i in range(for_mapping_df.shape[0]):
    lats.append(float(for_mapping_df.iloc[i]["Lat, long"].split(",")[0]))
    longs.append(float(for_mapping_df.iloc[i]["Lat, long"].split(",")[1]))
for_mapping_df["Latitude"] = lats
for_mapping_df["Longitude"] = longs

# %%
for_mapping_df.to_csv("Updated df.csv")

# %% [markdown]
# ## Cleaning out more stopwords
# NLTK's 'english' stopwords don't seem to have done an adequate job, so I'm using sci-kit learn's

# %%
def clean_again(review):

    cleaned_review = ''
    cleaned_words = 0
    for word in review.split():
        if word not in ENGLISH_STOP_WORDS:
            cleaned_review += word + ' '
        else:
            cleaned_words += 1
    print(cleaned_words)

    return cleaned_review

# %%
main_df["Cleaned review v2"] = main_df["Cleaned review"].apply(lambda x: clean_again(x))
# Out:
# 2
# 7
# 9
# 8
# 1
# 6
# 7
# 2
# 1
# 2
# 8
# 3
# 9
# 2
# 11
# 6
# 0
# 9
# 10
# 5
# 5
# 17
# 17
# 18
# 5
# 13
# 3
# 7
# 6
# 8
# 15
# 12
# 8
# 6
# 9
# 4
# 4
# 2
# 6
# 7
# 9
# 5
# 3
# 17
# 12
# 8
# 1
# 5
# 5
# 10
# 1
# 10
# 11
# 15
# 10
# 5
# 1
# 7
# 11
# 13
# 12
# 7
# 10
# 17
# 11
# 12
# 4
# 8
# 14
# 3
# 4
# 4
# 18
# 7
# 2
# 5
# 6
# 12
# 5
# 11
# 4
# 5
# 3
# 16
# 4
# 2
# 17
# 4
# 5
# 1
# 2
# 15
# 5
# 17
# 8
# 3
# 5
# 13
# 8
# 14
# 7
# 10
# 24
# 13
# 4
# 8
# 7
# 5
# 5
# 11
# 15
# 9
# 9
# 8
# 18
# 8
# 15
# 12
# 5
# 9
# 5
# 3
# 13
# 10
# 12
# 13
# 13
# 15
# 15
# 6
# 3
# 16
# 7
# 0
# 13
# 17
# 7
# 7
# 9
# 4
# 11
# 3
# 9
# 6
# 13
# 13
# 15
# 8
# 11
# 3
# 10
# 11
# 3
# 10
# 5
# 2
# 3
# 6
# 9
# 1
# 5
# 8
# 11
# 7
# 2
# 3
# 11
# 4
# 19
# 7
# 11
# 4
# 14
# 19
# 5
# 6
# 10
# 9
# 12
# 3
# 22
# 2
# 14
# 9
# 6
# 8
# 11
# 8
# 9
# 15
# 12
# 11
# 18
# 15
# 14
# 8
# 10
# 11
# 0
# 7
# 2
# 6
# 21
# 5
# 1
# 10
# 8
# 3
# 8
# 4
# 16
# 15
# 15
# 15
# 4
# 9
# 5
# 13
# 10
# 10
# 10
# 1
# 9
# 17
# 8
# 8
# 19
# 9
# 3
# 6
# 10
# 2
# 1
# 22
# 4
# 11
# 3
# 11
# 7
# 11
# 23
# 15
# 11
# 12
# 11
# 5
# 1
# 3
# 6
# 19
# 11
# 19
# 6
# 9
# 6
# 0
# 7
# 13
# 3
# 3
# 13
# 15
# 6
# 4
# 10
# 4
# 10
# 20
# 6
# 13
# 4
# 1
# 2
# 11
# 10
# 8
# 14
# 6
# 4
# 7
# 7
# 2
# 11
# 7
# 4
# 11
# 10
# 11
# 12
# 9
# 0
# 5
# 47
# 5
# 16
# 30
# 4
# 6
# 11
# 5
# 2
# 11
# 10
# 9
# 12
# 7
# 13
# 14
# 10
# 4
# 4
# 15
# 1
# 11
# 6
# 14
# 10
# 15
# 10
# 11
# 0
# 6
# 1
# 18
# 13
# 5
# 6
# 3
# 18
# 4
# 9
# 1
# 10
# 5
# 3
# 6
# 5
# 19
# 2
# 32
# 10
# 6
# 10
# 8
# 12
# 9
# 15
# 8
# 3
# 13
# 22
# 5
# 19
# 18
# 12
# 10
# 8
# 8
# 2
# 2
# 16
# 3
# 5
# 4
# 15
# 11
# 5
# 1

# %%
results_df = run_model(main_df, "nmf", 8, results_df=True, ngram_range=(1,2))
# Out:
# Topic 1
# ['small', 'nice', 'bathroom', 'night', 'bed']
#
# Topic 2
# ['wonderful', 'view', 'breakfast', 'place', 'great']
#
# Topic 3
# ['owner', 'creek', 'stay cabin', 'cabin clean', 'cabin']
#
# Topic 4
# ['day', 'trip', 'fish', 'lodge', 'fishing']
#
# Topic 5
# ['view', 'restaurant', 'lodge', 'park', 'denali']
#
# Topic 6
# ['clean', 'staff friendly', 'helpful', 'friendly', 'staff']
#
# Topic 7
# ['downtown', 'restaurant', 'stay hotel', 'anchorage', 'hotel']
#
# Topic 8
# ['downtown', 'service', 'free', 'airport', 'shuttle']

# %%
top_words(main_df, 100)
# Out:
# 1. ('room', 95733)
# 2. ('stay', 79677)
# 3. ('hotel', 49682)
# 4. ('great', 41285)
# 5. ('good', 38315)
# 6. ('clean', 36405)
# 7. ('place', 35089)
# 8. ('breakfast', 34819)
# 9. ('night', 33833)
# 10. ('staff', 32329)
# 11. ('nice', 30199)
# 12. ('one', 28315)
# 13. ('would', 27430)
# 14. ('get', 26978)
# 15. ('well', 25153)
# 16. ('bed', 24154)
# 17. ('make', 23851)
# 18. ('view', 23321)
# 19. ('go', 23163)
# 20. ('day', 23061)
# 21. ('cabin', 22246)
# 22. ('lodge', 22197)
# 23. ('time', 21468)
# 24. ('not', 21174)
# 25. ('friendly', 20651)
# 26. ('restaurant', 19088)
# 27. ('alaska', 18971)
# 28. ('area', 18586)
# 29. ('location', 17372)
# 30. ('could', 16969)
# 31. ('like', 16776)
# 32. ('trip', 15885)
# 33. ('two', 15366)
# 34. ('need', 15366)
# 35. ('helpful', 15311)
# 36. ('walk', 15309)
# 37. ('food', 15055)
# 38. ('take', 14970)
# 39. ('back', 14161)
# 40. ('service', 13909)
# 41. ('small', 13200)
# 42. ('want', 13130)
# 43. ('see', 12947)
# 44. ('really', 12375)
# 45. ('anchorage', 12315)
# 46. ('find', 12030)
# 47. ('bathroom', 11913)
# 48. ('beautiful', 11710)
# 49. ('even', 11649)
# 50. ('enjoy', 11378)
# 51. ('close', 11212)
# 52. ('look', 11149)
# 53. ('town', 10961)
# 54. ('denali', 10958)
# 55. ('experience', 10952)
# 56. ('park', 10853)
# 57. ('front', 10781)
# 58. ('shuttle', 10766)
# 59. ('wonderful', 10722)
# 60. ('first', 10432)
# 61. ('lot', 10394)
# 62. ('everything', 10364)
# 63. ('feel', 10333)
# 64. ('desk', 10190)
# 65. ('little', 10119)
# 66. ('do', 9991)
# 67. ('next', 9946)
# 68. ('people', 9670)
# 69. ('use', 9507)
# 70. ('book', 9444)
# 71. ('right', 9416)
# 72. ('airport', 9393)
# 73. ('tour', 9326)
# 74. ('check', 9222)
# 75. ('large', 9164)
# 76. ('love', 9142)
# 77. ('much', 9125)
# 78. ('family', 9123)
# 79. ('give', 9097)
# 80. ('visit', 9082)
# 81. ('work', 9081)
# 82. ('around', 9005)
# 83. ('way', 8998)
# 84. ('say', 8960)
# 85. ('home', 8940)
# 86. ('downtown', 8919)
# 87. ('price', 8836)
# 88. ('morning', 8814)
# 89. ('fishing', 8718)
# 90. ('free', 8535)
# 91. ('excellent', 8521)
# 92. ('coffee', 8387)
# 93. ('didst', 8384)
# 94. ('owner', 8014)
# 95. ('guest', 7950)
# 96. ('arrive', 7922)
# 97. ('every', 7691)
# 98. ('quiet', 7687)
# 99. ('shower', 7624)
# 100. ('inn', 7525)

# %% [markdown]
# ## Trying CorEx

# %%
from corextopic import corextopic as ct

# %%
corpus = main_df['Cleaned review v2']
tfidf = TfidfVectorizer(stop_words="english", max_df=0.5, max_features=None, ngram_range=(1, 3), norm=None, binary=True, sublinear_tf=False)
df_vectorized = tfidf.fit_transform(corpus)
vocab = tfidf.get_feature_names()

# %%
df_vectorized.toarray().shape
# Out:
# (94513, 3964545)

# %%
# This is for comparing with the results in the cell below

corex = ct.Corex(n_hidden=5, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors=[["hotel", "lodge"], ["aurora", "northern lights"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-829accd18ff5> in <module>
#       2
#       3 corex = ct.Corex(n_hidden=5, seed=10)
# ----> 4 corex = corex.fit(df_vectorized, words=vocab, anchors=[["hotel", "lodge"], ["aurora", "northern lights"]])
#       5
#       6 for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/corextopic/corextopic.py in fit(self, X, y, anchors, anchor_strength, words, docs)
#     151         Fit CorEx on the data X. See fit_transform.
#     152         """
# --> 153         self.fit_transform(X, anchors=anchors, anchor_strength=anchor_strength, words=words, docs=docs)
#     154         return self
#     155
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/corextopic/corextopic.py in fit_transform(self, X, y, anchors, anchor_strength, words, docs)
#     195
#     196             if nloop > 0:  # Structure learning step
# --> 197                 self.alpha = self.calculate_alpha(X, p_y_given_x, self.theta, self.log_p_y, self.tcs)
#     198             if anchors is not None:
#     199                 for a in flatten(anchors):
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/corextopic/corextopic.py in calculate_alpha(self, X, p_y_given_x, theta, log_p_y, tcs)
#     410             for i in np.where((mis == maxmis).sum(axis=0))[0]:  # Break ties for the largest MI
#     411                 mis[:, i] += 1e-10 * np.random.random(self.n_hidden)
# --> 412                 maxmis[i] = np.max(mis[:, i])
#     413             with np.errstate(under='ignore'):
#     414                 alphaopt = np.exp(t * (mis - maxmis) / self.h_x)
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/numpy/core/fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2703     5
#    2704     """
# -> 2705     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2706                           keepdims=keepdims, initial=initial, where=where)
#    2707
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      68
#      69
# ---> 70 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
#      71     passkwargs = {k: v for k, v in kwargs.items()
#      72                   if v is not np._NoValue}
#
# KeyboardInterrupt:

# %%
corex = ct.Corex(n_hidden=5, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))
# Out:
# Topic #1: hotel, shuttle, desk, lobby, restaurant, airport
# Topic #2: aurora, light, boreal, northern, like, aurora boreal, know, guest, want, northern light
# Topic #3: fishing, fish, guide, salmon, catch, halibut, trip, bear, boat, experience
# Topic #4: coffee, microwave, bed, bathroom, fruit, egg, fridge, tv, kitchen, cereal
# Topic #5: outdoor, email, cool, write, young, furnish, kind, arrangement, creamer, landscape

# %%
corex = ct.Corex(n_hidden=10, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = ["hotel", "lodge", "cabin"])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))
# Out:
# Topic #1: hotel, desk, shuttle, staff, lobby, restaurant, service, stay hotel
# Topic #2: lodge, fishing, fish, guide, national park, national, river, denali, salmon, denali national
# Topic #3: cabin, view, beautiful, mountain, lake, glacier, deck, enjoy, cabin clean, stay cabin
# Topic #4: day, trip, alaska, dinner, meal, spend, trip alaska, lunch, week, adventure
# Topic #5: breakfast, bb, living, fruit, bedroom, egg, house, delicious, kitchen, living room
# Topic #6: bed, floor, microwave, tv, fridge, smell, small, carpet, wall, door
# Topic #7: arrive, check, tell, say, review, book, ask, late, leave, reservation
# Topic #8: make, home, feel, experience, make feel, thank, wonderful, family, year, feel like
# Topic #9: bathroom, shower, main, outside, water, building, large, window, chair, table
# Topic #10: downtown, airport, walk, distance, walk distance, locate, train, free, close, location

# %%
corex_details = {"Topics": 10, "Anchors": [["hotel", "lodge", "cabin"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 2), "Words": corex.words, "Other": "min_df=5"}

# %%
corex_df = corex_df.append(corex_details, ignore_index=True)

# %%
with open("corex_df.pickle", "wb") as to_write:
    pickle.dump(corex_df, to_write)

# %%
corex = ct.Corex(n_hidden=5, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["staff"], ["nature"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))
# Out:
# Topic #1: hotel, desk, floor, shuttle, cruise, lobby, bad, princess
# Topic #2: cabin, host, bb, beautiful, house, owner, denali, view
# Topic #3: fishing, fish, guide, trip, salmon, bear, experience, boat, catch, halibut
# Topic #4: walk, downtown, distance, restaurant, microwave, free, bed, small, walk distance, shop
# Topic #5: arrive, tell, say, check, day, leave, book, didst, night, review

# %%
for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))
# Out:
# Topic #1: hotel, desk, floor, shuttle, cruise, lobby, bad, princess
# Topic #2: cabin, host, bb, beautiful, house, owner, denali, view
# Topic #3: fishing, fish, guide, trip, salmon, bear, experience, boat, catch, halibut
# Topic #4: walk, downtown, distance, restaurant, microwave, free, bed, small, walk distance, shop
# Topic #5: arrive, tell, say, check, day, leave, book, didst, night, review

# %%
corex = ct.Corex(n_hidden=5, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["nature", "beautiful"], ["breakfast", "cereal"], ["check", "staff"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))
# Out:
# Topic #1: hotel, floor, didst, open, tell, bad, door, window, night, pay
# Topic #2: fishing, fish, guide, trip, experience, home, salmon, make, bear, alaska
# Topic #3: coffee, breakfast, bed, microwave, kitchen, fridge, bedroom, bathroom, fruit, tv
# Topic #4: cabin, host, bb, owner, denali, park, house

# %%
corex = ct.Corex(n_hidden=5, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["nature", "beautiful"], ["breakfast", "cereal"], ["check", "staff"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))
# Out:
# Topic #1: hotel, floor, restaurant, shuttle, cruise, lobby, small, princess, window, walk
# Topic #2: fishing, fish, guide, trip, salmon, experience, bear, amazing, home, beautiful
# Topic #3: coffee, bed, microwave, breakfast, kitchen, fridge, bathroom, bedroom, fruit, tv
# Topic #4: cabin, host, bb, denali, owner, park, house
# Topic #5: arrive, tell, say, book, didst, review, leave, ask, day, want

# %%
corex_details = {"Topics": 5, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 2), "Words": corex.words, "Other": "min_df=5"}
# Out:
# Topic #1: hotel, floor, restaurant, shuttle, cruise, lobby, small, princess, window, walk
# Topic #2: fishing, fish, guide, trip, salmon, experience, bear, amazing, home, beautiful
# Topic #3: coffee, bed, microwave, breakfast, kitchen, fridge, bathroom, bedroom, fruit, tv
# Topic #4: cabin, host, bb, denali, owner, park, house
# Topic #5: arrive, tell, say, book, didst, review, leave, ask, day, want

# %%
corex_df = corex_df.append(corex_details, ignore_index=True)

# %%
corex = ct.Corex(n_hidden=4, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 4, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 2), "Words": corex.words, "Other": "min_df=5"}

corex_df = corex_df.append(corex_details, ignore_index=True)

# %%
corex = ct.Corex(n_hidden=5, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 5, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 2), "Words": corex.words, "Other": "min_df=5"}

corex_df = corex_df.append(corex_details, ignore_index=True)
# Out:
# Topic #1: hotel, shuttle, restaurant, airport, desk, downtown, lobby, cruise, free, staff
# Topic #2: fishing, fish, guide, trip, salmon, catch, boat, bear, halibut, experience
# Topic #3: cabin, denali, view, park, mountain, beautiful, river, national park, national, deck
# Topic #4: host, home, bb, make, wonderful, feel, delicious, make feel, house, amazing
# Topic #5: bed, bathroom, floor, didst, tell, night, door, tv, shower, window

# %%
corex = ct.Corex(n_hidden=6, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 6, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 2), "Words": corex.words, "Other": "min_df=5"}

corex_df = corex_df.append(corex_details, ignore_index=True)
# Out:
# Topic #1: hotel, shuttle, desk, staff, airport, restaurant, lobby
# Topic #2: fishing, fish, guide, salmon, trip, catch, bear, boat, halibut, day
# Topic #3: make, home, experience, wonderful, feel, thank, amazing, family, make feel, alaska
# Topic #4: breakfast, view, bb, beautiful, mountain, delicious, enjoy, fruit, deck, egg
# Topic #5: bathroom, bed, small, shower, tv, microwave, window, floor, fridge, coffee
# Topic #6: tell, say, check, arrive, didst, review, bad, ask, dirty, book

# %%
corex = ct.Corex(n_hidden=7, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 7, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 2), "Words": corex.words, "Other": "min_df=5"}

corex_df = corex_df.append(corex_details, ignore_index=True)
# Out:
# Topic #1: hotel, desk, shuttle, staff, lobby, airport
# Topic #2: denali, park, national park, national, kitchen, fruit, living, bedroom, egg, denali national
# Topic #3: arrive, check, tell, say, book, review, leave, early, late, day
# Topic #4: bed, bathroom, shower, microwave, floor, tv, small, window, fridge, door
# Topic #5: downtown, walk, distance, shop, restaurant, walk distance, locate, location, free, town
# Topic #6: view, beautiful, mountain, enjoy, glacier, deck, bay, homer, wonderful, amazing
# Topic #7: fishing, fish, guide, trip, salmon, bear, experience, catch, boat, halibut

# %%
corex = ct.Corex(n_hidden=8, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 8, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 2), "Words": corex.words, "Other": "min_df=5"}

corex_df = corex_df.append(corex_details, ignore_index=True)
# Out:
# Topic #1: hotel, shuttle, desk, staff, lobby, airport, service
# Topic #2: kitchen, arrive, night, bedroom, book, review, living, late, early, queen
# Topic #3: cabin, denali, park, national park, national, river, talkeetna, denali national, mckinley, cabin clean
# Topic #4: view, beautiful, mountain, enjoy, wonderful, amazing, glacier, bay, lake, homer
# Topic #5: fishing, fish, guide, trip, salmon, experience, catch, bear, halibut, boat
# Topic #6: breakfast, coffee, microwave, fridge, continental, fruit, continental breakfast, egg, bed, cereal
# Topic #7: floor, bathroom, window, open, door, tell, shower, smell, bad, didst
# Topic #8: downtown, walk, distance, shop, restaurant, walk distance, locate, location, town, street

# %%
corex = ct.Corex(n_hidden=9, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 9, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 2), "Words": corex.words, "Other": "min_df=5"}

corex_df = corex_df.append(corex_details, ignore_index=True)
# Out:
# Topic #1: hotel, staff, desk, shuttle, lobby
# Topic #2: view, mountain, beautiful, glacier, deck, lake, bay, enjoy, bear, spectacular
# Topic #3: food, river, dinner, tour, princess, lunch, meal, land, eat, holland
# Topic #4: floor, bathroom, window, shower, smell, door, wall, carpet, open, noise
# Topic #5: arrive, check, tell, say, late, book, ask, leave, reservation, early
# Topic #6: fishing, fish, guide, trip, salmon, catch, experience, halibut, boat, fishing trip
# Topic #7: downtown, walk, distance, shop, walk distance, restaurant, locate, location, train, town
# Topic #8: bed, coffee, microwave, kitchen, fridge, bedroom, tv, breakfast, queen, living
# Topic #9: park, denali, national, national park, rv, denali national, road, site, rv park, entrance

# %%
corex = ct.Corex(n_hidden=10, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 10, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 2), "Words": corex.words, "Other": "min_df=5"}

corex_df = corex_df.append(corex_details, ignore_index=True)
# Out:
# Topic #1: hotel, shuttle, desk, staff, airport, lobby, free, stay hotel
# Topic #2: bathroom, bed, kitchen, microwave, tv, shower, fridge, bedroom, coffee, queen
# Topic #3: fishing, fish, guide, trip, experience, salmon, bear, make, catch, home
# Topic #4: denali, tour, park, national park, national, princess, dinner, denali national, mckinley, bus
# Topic #5: breakfast, bb, delicious, fruit, egg, cereal, house, juice, fresh, sausage
# Topic #6: floor, noise, bad, window, dirty, carpet, smell, open, door, wall
# Topic #7: arrive, check, tell, say, book, review, late, leave, early, day
# Topic #8: downtown, walk, distance, shop, restaurant, walk distance, locate, location, town, close
# Topic #9: view, mountain, beautiful, great view, deck, overlook, view room, beautiful view, sit, main
# Topic #10: cabin, rv, homer, cabin clean, stay cabin, campground, rv park, beach, creek, pit

# %%
corex = ct.Corex(n_hidden=4, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 4, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 3), "Words": corex.words, "Other": "min_df=7, max_df=0.4"}

corex_df = corex_df.append(corex_details, ignore_index=True)
# Out:
# Topic #1: hotel, shuttle, desk, lobby, restaurant, airport, cruise
# Topic #2: bathroom, bed, small, shower, tv, microwave, park, kitchen, night, denali
# Topic #3: fishing, fish, guide, trip, make, home, experience, beautiful, salmon, bear
# Topic #4: breakfast, bb, continental, continental breakfast, downtown, fruit, buffet, breakfast good, egg, morning

# %%
corex = ct.Corex(n_hidden=5, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 5, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 3), "Words": corex.words, "Other": "min_df=7, max_df=0.4"}

corex_df = corex_df.append(corex_details, ignore_index=True)
# Out:
# Topic #1: hotel, floor, desk, check, didst, tell, open, bad, door, bathroom
# Topic #2: cabin, host, bb, owner, home, kitchen, house, feel
# Topic #3: fishing, fish, guide, trip, view, salmon, bear, boat, beautiful, experience
# Topic #4: breakfast, continental, buffet, breakfast good, fruit, continental breakfast, egg, bed breakfast, morning, breakfast morning
# Topic #5: walk, downtown, distance, park, restaurant, shop, walk distance, locate, denali, microwave

# %%
corex = ct.Corex(n_hidden=6, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 6, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 3), "Words": corex.words, "Other": "min_df=7, max_df=0.4"}

corex_df = corex_df.append(corex_details, ignore_index=True)
# Out:
# Topic #1: hotel, shuttle, restaurant, airport, downtown, cruise, walk, distance, staff, walk distance
# Topic #2: host, home, make, wonderful, bb, trip, feel, experience, make feel, amazing
# Topic #3: cabin, denali, fishing, river, view, fish, park, national park, national, guide
# Topic #4: breakfast, continental, buffet, breakfast good, fruit, continental breakfast, egg, bed breakfast, morning, breakfast morning
# Topic #5: bed, bathroom, floor, microwave, tv, shower, window, small, fridge, sink
# Topic #6: arrive, check, tell, say, book, review, desk, ask, leave, didst

# %%
corex = ct.Corex(n_hidden=7, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 7, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 3), "Words": corex.words, "Other": "min_df=7, max_df=0.4"}

corex_df = corex_df.append(corex_details, ignore_index=True)
# Out:
# Topic #1: hotel, shuttle, restaurant, airport, downtown, walk, cruise, distance, staff, walk distance
# Topic #2: host, home, make, wonderful, bb, feel, trip, alaska, make feel, experience
# Topic #3: cabin, denali, fishing, fish, river, park, guide, national park, national, salmon
# Topic #4: breakfast, continental, buffet, breakfast good, fruit, continental breakfast, egg, bed breakfast, breakfast morning, morning
# Topic #5: bathroom, bed, kitchen, microwave, shower, tv, fridge, bedroom, small, queen
# Topic #6: floor, window, noise, door, smell, open, carpet, wall, dirty, bad
# Topic #7: arrive, check, tell, say, desk, book, review, late, reservation, ask

# %%
corex = ct.Corex(n_hidden=8, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 8, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 3), "Words": corex.words, "Other": "min_df=7, max_df=0.4"}

corex_df = corex_df.append(corex_details, ignore_index=True)
# Out:
# Topic #1: hotel, shuttle, airport, desk, cruise, lobby, shuttle service, stay hotel, hotel room, free
# Topic #2: make, home, feel, alaska, make feel, feel like, make sure, day, family, time
# Topic #3: fishing, fish, guide, salmon, trip, bear, boat, catch, halibut, experience
# Topic #4: breakfast, continental, buffet, breakfast good, fruit, continental breakfast, egg, bed breakfast, morning, breakfast morning
# Topic #5: bed, bathroom, floor, microwave, tv, window, shower, door, open, didst
# Topic #6: host, bb, kitchen, house, owner, homer, private, wonderful, beautiful
# Topic #7: cabin, denali, park, view, mountain, national park, national, river, main, denali national
# Topic #8: downtown, walk, restaurant, distance, shop, walk distance, location, locate, close, street

# %%
corex = ct.Corex(n_hidden=9, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 9, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 3), "Words": corex.words, "Other": "min_df=7, max_df=0.4"}

corex_df = corex_df.append(corex_details, ignore_index=True)
# Out:
# Topic #1: hotel, shuttle, restaurant, staff, airport, cruise, lobby, desk, free
# Topic #2: host, home, make, bb, feel, wonderful, make feel, house, alaska, family
# Topic #3: fishing, fish, guide, trip, salmon, bear, boat, catch, halibut, experience
# Topic #4: breakfast, continental, buffet, breakfast good, fruit, continental breakfast, egg, bed breakfast, morning, breakfast morning
# Topic #5: cabin, denali, view, mountain, park, beautiful, national park, national, river, deck
# Topic #6: arrive, check, say, tell, review, book, leave, reservation, late, ask
# Topic #7: downtown, walk, distance, walk distance, locate, location, harbour, seward, town, easy
# Topic #8: floor, window, noise, smell, carpet, door, open, dirty, wall, air
# Topic #9: bathroom, bed, shower, microwave, tv, kitchen, fridge, small, queen, bedroom

# %%
corex = ct.Corex(n_hidden=10, seed=10)
corex = corex.fit(df_vectorized, words=vocab, anchors = [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"]])

for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    print("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 10, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"], ["nature"], ["breakfast"]], "TC": corex.tc, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "N-gram range": (1, 3), "Words": corex.words, "Other": "min_df=7, max_df=0.4"}

corex_df = corex_df.append(corex_details, ignore_index=True)
# Out:
# Topic #1: hotel, shuttle, desk, airport, lobby, stay hotel, service, shuttle service
# Topic #2: night, arrive, early, late, day, living, spend, living room, flight, stay night
# Topic #3: fishing, fish, guide, trip, salmon, bear, boat, catch, halibut, lake
# Topic #4: breakfast, continental, breakfast good, buffet, fruit, continental breakfast, egg, bed breakfast, breakfast morning, morning
# Topic #5: tell, floor, didst, say, bad, open, window, door, smell, dirty
# Topic #6: host, home, make, wonderful, bb, feel, make feel, amazing, beautiful, delicious
# Topic #7: denali, park, tour, national park, national, princess, denali national, denali national park, mckinley, cruise
# Topic #8: shop, walk, microwave, wifi, restaurant, rv, fridge, laundry, street, coffee
# Topic #9: friendly, downtown, staff, helpful, staff friendly, friendly helpful, distance, walk distance, location, staff friendly helpful
# Topic #10: bathroom, bed, kitchen, shower, bedroom, tub, queen, hot, tv, bath

# %%
corex_df
# Out:
#    Topics                                            Anchors         TC  \
# 0       5        [[hotel, lodge], [aurora, northern lights]]  22.554910
# 1       6                            [[hotel, lodge, cabin]]  15.937173
# 2      10                            [[hotel, lodge, cabin]]  18.508590
# 3       5                [[hotel, lodge], [staff], [nature]]  14.338410
# 4       4  [[hotel, lodge], [nature, beautiful], [breakfa...  13.616512
# 5       5  [[hotel, lodge], [nature, beautiful], [breakfa...  14.569744
# 6       5        [[hotel, lodge], [aurora, northern lights]]  14.935271
# 7       6        [[hotel, lodge], [aurora, northern lights]]  15.518759
# 8       7        [[hotel, lodge], [aurora, northern lights]]  16.810080
# 9       8        [[hotel, lodge], [aurora, northern lights]]  17.540303
# 10      9        [[hotel, lodge], [aurora, northern lights]]  18.746688
# 11     10        [[hotel, lodge], [aurora, northern lights]]  19.444893
# 12      4  [[hotel, lodge], [aurora, northern lights], [n...  13.948293
# 13      5  [[hotel, lodge], [aurora, northern lights], [n...  15.666989
# 14      6  [[hotel, lodge], [aurora, northern lights], [n...  17.072862
# 15      7  [[hotel, lodge], [aurora, northern lights], [n...  18.133663
# 16      8  [[hotel, lodge], [aurora, northern lights], [n...  18.792481
# 17      9  [[hotel, lodge], [aurora, northern lights], [n...  20.196478
# 18     10  [[hotel, lodge], [aurora, northern lights], [n...  20.455128
#
#                                                Labels  \
# 0   [[True, False, True, False, False], [False, Fa...
# 1   [[True, False, False, False, True, False], [Fa...
# 2   [[True, False, False, False, False, True, Fals...
# 3   [[True, False, False, True, False], [False, Fa...
# 4   [[True, False, True, False], [False, False, Fa...
# 5   [[True, False, True, False, False], [False, Fa...
# 6   [[True, False, False, False, True], [False, Fa...
# 7   [[True, False, False, False, True, False], [Tr...
# 8   [[True, False, False, True, True, False, False...
# 9   [[True, False, False, False, False, True, True...
# 10  [[True, False, False, True, False, False, True...
# 11  [[True, True, False, False, False, True, False...
# 12  [[True, True, False, True], [False, False, Fal...
# 13  [[True, False, False, True, True], [False, Fal...
# 14  [[True, False, False, True, True, False], [Fal...
# 15  [[True, False, False, True, True, True, False]...
# 16  [[True, False, False, True, True, False, False...
# 17  [[False, False, False, True, False, False, Tru...
# 18  [[True, False, False, True, False, False, Fals...
#
#                                              Clusters  \
# 0   [0, 0, 4, 1, 2, 3, 1, 0, 4, 1, 0, 1, 3, 0, 4, ...
# 1   [5, 0, 5, 0, 0, 1, 5, 0, 1, 5, 5, 1, 3, 0, 0, ...
# 2   [8, 6, 6, 0, 6, 7, 6, 0, 1, 6, 8, 3, 6, 7, 7, ...
# 3   [1, 0, 4, 0, 3, 2, 0, 1, 0, 0, 4, 0, 4, 0, 0, ...
# 4   [2, 0, 0, 0, 0, 1, 0, 3, 3, 0, 0, 0, 0, 1, 3, ...
# 5   [2, 0, 4, 0, 0, 1, 4, 3, 3, 4, 4, 0, 4, 1, 3, ...
# 6   [1, 4, 4, 4, 4, 1, 3, 4, 2, 1, 4, 1, 2, 3, 3, ...
# 7   [1, 0, 0, 2, 0, 1, 0, 0, 4, 5, 4, 5, 5, 2, 0, ...
# 8   [2, 0, 0, 0, 3, 6, 0, 0, 1, 6, 3, 5, 2, 0, 0, ...
# 9   [4, 0, 0, 0, 6, 4, 0, 0, 2, 6, 6, 3, 1, 0, 0, ...
# 10  [8, 0, 0, 0, 0, 5, 0, 0, 2, 5, 3, 2, 4, 0, 0, ...
# 11  [6, 5, 6, 5, 5, 2, 5, 0, 8, 6, 5, 3, 6, 0, 4, ...
# 12  [1, 0, 0, 0, 0, 2, 0, 0, 1, 0, 1, 0, 0, 1, 1, ...
# 13  [2, 0, 1, 0, 0, 2, 0, 0, 4, 0, 0, 1, 1, 0, 4, ...
# 14  [5, 4, 5, 4, 4, 1, 1, 2, 2, 5, 4, 1, 1, 4, 3, ...
# 15  [6, 5, 6, 5, 5, 1, 1, 6, 2, 6, 5, 1, 1, 5, 5, ...
# 16  [6, 4, 4, 4, 4, 2, 5, 4, 6, 2, 4, 5, 3, 4, 2, ...
# 17  [5, 7, 5, 7, 7, 2, 5, 4, 4, 5, 7, 1, 1, 7, 7, ...
# 18  [2, 0, 0, 0, 8, 2, 4, 4, 6, 4, 4, 5, 5, 8, 4, ...
#
#                                                 Alpha  \
# 0   [[1.0, 1.0, 1.2850321286285925e-100, 1.4588700...
# 1   [[9.489863603125979e-09, 1.0, 6.91939798213093...
# 2   [[0.0002204576955178804, 8.867403279881514e-21...
# 6   [aa, aaa, aaa book, aaa discount, aaa rate, aa...              min_df=5
# 7   [aa, aaa, aaa book, aaa discount, aaa rate, aa...              min_df=5
# 8   [aa, aaa, aaa book, aaa discount, aaa rate, aa...              min_df=5
# 9   [aa, aaa, aaa book, aaa discount, aaa rate, aa...              min_df=5
# 10  [aa, aaa, aaa book, aaa discount, aaa rate, aa...              min_df=5
# 11  [aa, aaa, aaa book, aaa discount, aaa rate, aa...              min_df=5
# 12  [aa, aaa, aaa book, aaa discount, aaa rate, aa...  min_df=7, max_df=0.4
# 13  [aa, aaa, aaa book, aaa discount, aaa rate, aa...  min_df=7, max_df=0.4
# 14  [aa, aaa, aaa book, aaa discount, aaa rate, aa...  min_df=7, max_df=0.4
# 15  [aa, aaa, aaa book, aaa discount, aaa rate, aa...  min_df=7, max_df=0.4
# 16  [aa, aaa, aaa book, aaa discount, aaa rate, aa...  min_df=7, max_df=0.4
# 17  [aa, aaa, aaa book, aaa discount, aaa rate, aa...  min_df=7, max_df=0.4
# 18  [aa, aaa, aaa book, aaa discount, aaa rate, aa...  min_df=7, max_df=0.4

# %%
model_list = []
tcs_list = []
topics_list = []
tcs_list = []
p_y_list = []
tc_history_list = []
top_docs_list = []
for i in range(corex_df.shape[0]):
          
    topics = corex_df.iloc[i]["Topics"]
    anchors = corex_df.iloc[i]["Anchors"]
    ngrams = corex_df.iloc[i]["N-gram range"]
    if corex_df.iloc[i]["Other"] == "min_df=5":
        min_df = 5
        max_df = 0.5
    elif corex_df.iloc[i]["Other"] == "min_df=7, max_df=0.04":
        min_df = 7
        max_df = 0.4
    else:
        min_df = 0
        max_df = 0.5

    corpus = main_df['Cleaned review v2']
    tfidf = TfidfVectorizer(stop_words="english", max_df=max_df, min_df=min_df, max_features=None, ngram_range=ngrams, norm=None, binary=True, sublinear_tf=False)
    df_vectorized = tfidf.fit_transform(corpus)
    vocab = tfidf.get_feature_names()

    corex = ct.Corex(n_hidden=topics, seed=10)
    corex = corex.fit(df_vectorized, docs=corpus.values, words=vocab, anchors=anchors)
    model_list.append(corex)
    tcs_list.append(corex.tcs)
    p_y_list.append(corex.p_y_given_x)
    tc_history_list.append(corex.tc_history)
    topics = []
    top_docs_list.append(corex.get_top_docs())
    for i, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
        topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
        topics.append("Topic #{}: {}".format(i+1, ", ".join(topic_ngrams)))
    topics_list.append(topics)

# %% [markdown]
# # New start

# %%
import pandas as pd
import numpy as np
import pickle
from corextopic import corextopic as ct
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus = main_df['Cleaned review v2']
tfidf = TfidfVectorizer(stop_words="english", max_df=.5, min_df=5, ngram_range=(1, 2), binary=True)
df_vectorized = tfidf.fit_transform(corpus)
vocab = tfidf.get_feature_names()

# %%
new_corex_df = pd.DataFrame(columns=["Topics", "Anchors", "Topic words", "TC", "TCs", "Labels", "Clusters", "Alpha", "Mis", "P(y)|x", "Words", "N-gram range", "min_df", "max_df"])
for i in tqdm(range(3, 21)):
    corex = ct.Corex(n_hidden=i, seed=10)
    corex = corex.fit(df_vectorized, anchors=[["hotel", "lodge"], ["aurora", "northern lights"]], docs=corpus.values, words=vocab)
    topic_words = []
    for x, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
        topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
        topic_words.append("Topic #{}: {}".format(x+1, ", ".join(topic_ngrams)))

    corex_details = {"Topics": i, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"]], "Topic words": topic_words, "TC": corex.tc, "TCs": corex.tcs, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "P(y)|x": corex.p_y_given_x, "Words": corex.words, "N-gram range": (1, 2), "min_df": 5, "max_df": 0.5}

    new_corex_df = new_corex_df.append(corex_details, ignore_index=True)

    with open("corex_df.pickle", "wb") as to_write:
        pickle.dump(new_corex_df, to_write)
    print(f'Finished with i: {i}')
# Out:
#   6%|▌         | 1/18 [04:27<1:15:46, 267.45s/it]Finished with i: 3
#  11%|█         | 2/18 [09:32<1:14:20, 278.77s/it]Finished with i: 4
#  17%|█▋        | 3/18 [15:12<1:14:14, 296.96s/it]Finished with i: 5
#  22%|██▏       | 4/18 [21:24<1:14:33, 319.56s/it]Finished with i: 6
#  28%|██▊       | 5/18 [28:13<1:15:02, 346.33s/it]Finished with i: 7
#  33%|███▎      | 6/18 [34:49<1:12:15, 361.29s/it]Finished with i: 8
#  39%|███▉      | 7/18 [39:33<1:01:59, 338.11s/it]Finished with i: 9
#  44%|████▍     | 8/18 [45:04<55:59, 335.94s/it]  Finished with i: 10
#  50%|█████     | 9/18 [47:48<42:41, 284.58s/it]Finished with i: 11
#  56%|█████▌    | 10/18 [53:05<39:12, 294.04s/it]Finished with i: 12
#  61%|██████    | 11/18 [59:46<38:03, 326.26s/it]Finished with i: 13
#  67%|██████▋   | 12/18 [1:06:33<35:03, 350.54s/it]Finished with i: 14
#  72%|███████▏  | 13/18 [1:13:57<31:32, 378.56s/it]Finished with i: 15
#  78%|███████▊  | 14/18 [1:21:36<26:51, 402.78s/it]Finished with i: 16
#  83%|████████▎ | 15/18 [1:29:22<21:04, 421.55s/it]Finished with i: 17
#  89%|████████▉ | 16/18 [1:36:36<14:10, 425.41s/it]Finished with i: 18
#  94%|█████████▍| 17/18 [1:44:24<07:18, 438.15s/it]Finished with i: 19
# 100%|██████████| 18/18 [1:53:57<00:00, 379.84s/it]Finished with i: 20

# %%
corpus = list(main_df['Cleaned review v2'])
tfidf = TfidfVectorizer(stop_words="english", max_df=.5, min_df=5, ngram_range=(1, 2), binary=True)
df_vectorized = tfidf.fit_transform(corpus)
vocab = tfidf.get_feature_names()


test = pd.DataFrame(columns=["Topics", "Anchors", "Topic words", "TC", "TCs", "Labels", "Clusters", "Alpha", "Mis", "P(y)|x", "Words", "N-gram range", "min_df", "max_df"])

corex = ct.Corex(n_hidden=9, seed=10)
corex = corex.fit(df_vectorized, anchors=[["hotel", "lodge"], ["aurora", "northern lights"]], words=vocab)
topic_words = []
for x, topic_ngrams in enumerate(corex.get_topics(n_words=10)):
    topic_ngrams = [ngram[0] for ngram in topic_ngrams if ngram[1] > 0]
    topic_words.append("Topic #{}: {}".format(x+1, ", ".join(topic_ngrams)))

corex_details = {"Topics": 9, "Anchors": [["hotel", "lodge"], ["aurora", "northern lights"]], "Topic words": topic_words, "TC": corex.tc, "TCs": corex.tcs, "Labels": corex.labels, "Clusters": corex.clusters, "Alpha": corex.alpha, "Mis": corex.mis, "P(y)|x": corex.p_y_given_x, "Words": corex.words, "N-gram range": (1, 2), "min_df": 5, "max_df": 0.5}

test = test.append(corex_details, ignore_index=True)

# %%
# topic_words
# Out:
# ['Topic #1: credit card, credit, cancel, card, reservation, email, confirmation, cancellation, cancel reservation, refund',
#  'Topic #2: fishing, fish, guide, catch, halibut, salmon, silver, captain, fishing trip, boat',
#  'Topic #3: treat grand, unique locally, unpaved trail, pave unpaved, path pave, grand lobby, crowd talkeetna, deck include, town unique, chair glass',
#  'Topic #4: meal photogenic, photogenic tasty, sparse hairdryers, unit similar, invite multiple, spa quality, decor sparse, configuration second, hairdryers coffee, toiletry spa',
#  'Topic #5: caravan sonnet, blog caravan, sonnet',
#  'Topic #6: egg, cereal, yogurt, fruit, juice, sausage, toast, bacon, biscuit, gravy',
#  'Topic #7: ',
#  'Topic #8: host, cabin, bb, wonderful, home, owner, beautiful',
#  'Topic #9: rv, campground, site, rv park, hookup, gravel, park, sewer, dump station, camper']

# %%
topic_words

# %% [markdown]
# # Getting nouns and adjs as features

# %%
# !pip install spacy[lookups]
import spacy
from collections import Counter
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy[lookups] in /opt/anaconda3/lib/python3.8/site-packages (2.3.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy[lookups]) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy[lookups]) (0.8.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /opt/anaconda3/lib/python3.8/site-packages (from spacy[lookups]) (1.0.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.8/site-packages (from spacy[lookups]) (49.6.0.post20200814)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /opt/anaconda3/lib/python3.8/site-packages (from spacy[lookups]) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy[lookups]) (2.0.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy[lookups]) (2.24.0)
# Requirement already satisfied: thinc==7.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from spacy[lookups]) (7.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy[lookups]) (1.0.4)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy[lookups]) (1.0.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy[lookups]) (3.0.4)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy[lookups]) (1.19.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy[lookups]) (4.49.0)
# Requirement already satisfied: spacy-lookups-data<0.4.0,>=0.3.2; extra == "lookups" in /opt/anaconda3/lib/python3.8/site-packages (from spacy[lookups]) (0.3.2)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy[lookups]) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy[lookups]) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy[lookups]) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy[lookups]) (1.25.10)
# Requirement already satisfied: en_core_web_sm==2.3.1 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz#egg=en_core_web_sm==2.3.1 in /opt/anaconda3/lib/python3.8/site-packages (2.3.1)
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from en_core_web_sm==2.3.1) (2.3.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.4)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.4)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.4)
# Requirement already satisfied: thinc==7.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (7.4.1)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.19.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.49.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (49.6.0.post20200814)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.8.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.24.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.25.10)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
def get_nouns(df):

    reviews = list(df["Cleaned review v2"])
    review_nouns_list = []

    for review in tqdm(reviews):
        review = nlp(review)
        review_nouns = []
        for word in tqdm(review):
            if word.lemma_ != "ovid" and (word.pos_ == "NOUN" or word.pos_ == "PROPN"):
                review_nouns.append(word.lemma_)
        nouns_only = " ".join(review_nouns)
        print(nouns_only)
        review_nouns_list.append(nouns_only)

    df["Review nouns"] = review_nouns_list
    
    return df

# %%
def get_adjs(review):

    review = nlp(review)
    review_adjs = []
    for token in review:
        if token.lemma_ != "ovid" and (token.pos_ == "NOUN" or token.pos_ == "PROPN"):
            review_nouns.append(token.lemma_)

    return " ".join(review_adjs)

# %%
def get_nouns(review):

    review = nlp(review)
    review_nouns = []
    for token in review:
        if token.lemma_ != "ovid" and (token.pos_ == "NOUN" or token.pos_ == "PROPN"):
            review_nouns.append(token.lemma_)

    return " ".join(review_nouns)

# %%
def get_adjs(review):

    review = nlp(review)
    review_adjs = []
    for token in review:
        if token.pos_ == "ADJ":
            review_adjs.append(token.lemma_)

    return " ".join(review_adjs)

# %%
review_adjs_list = []
for i in range(main_df.shape[0]):
    # checker_list.append(i)
    print(i)
    review_adjs_list.append(get_adjs(main_df.iloc[i]["Cleaned review v2"]))
# Out:
# 9
# 91180
# 91181
# 91182
# 91183
# 91184
# 91185
# 91186
# 91187
# 91188
# 91189
# 91190
# 91191
# 91192
# 91193
# 91194
# 91195
# 91196
# 91197
# 91198
# 91199
# 91200
# 91201
# 91202
# 91203
# 91204
# 91205
# 91206
# 91207
# 91208
# 91209
# 91210
# 91211
# 91212
# 91213
# 91214
# 91215
# 91216
# 91217
# 91218
# 91219
# 91220
# 91221
# 91222
# 91223
# 91224
# 91225
# 91226
# 91227
# 91228
# 91229
# 91230
# 91231
# 91232
# 91233
# 91234
# 91235
# 91236
# 91237
# 91238
# 91239
# 91240
# 91241
# 91242
# 91243
# 91244
# 91245
# 91246
# 91247
# 91248
# 91249
# 91250
# 91251
# 91252
# 91253
# 91254
# 91255
# 91256
# 91257
# 91258
# 91259
# 91260
# 91261
# 91262
# 91263
# 91264
# 91265
# 91266
# 91267
# 91268
# 91269
# 91270
# 91271
# 91272
# 91273
# 91274
# 91275
# 91276
# 91277
# 91278
# 91279
# 91280
# 91281
# 91282
# 91283
# 91284
# 91285
# 91286
# 91287
# 91288
# 91289
# 91290
# 91291
# 91292
# 91293
# 91294
# 91295
# 91296
# 91297
# 91298
# 91299
# 91300
# 91301
# 91302
# 91303
# 91304
# 91305
# 91306
# 91307
# 91308
# 91309
# 91310
# 91311
# 91312
# 91313
# 91314
# 91315
# 91316
# 91317
# 91318
# 91319
# 91320
# 91321
# 91322
# 91323
# 91324
# 91325
# 91326
# 91327
# 91328
# 91329
# 91330
# 91331
# 91332
# 91333
# 91334
# 91335
# 91336
# 91337
# 91338
# 91339
# 91340
# 91341
# 91342
# 91343
# 91344
# 91345
# 91346
# 91347
# 91348
# 91349
# 91350
# 91351
# 91352
# 91353
# 91354
# 91355
# 91356
# 91357
# 91358
# 91359
# 91360
# 91361
# 91362
# 91363
# 91364
# 91365
# 91366
# 91367
# 91368
# 91369
# 91370
# 91371
# 91372
# 91373
# 91374
# 91375
# 91376
# 91377
# 94471
# 94472
# 94473
# 94474
# 94475
# 94476
# 94477
# 94478
# 94479
# 94480
# 94481
# 94482
# 94483
# 94484
# 94485
# 94486
# 94487
# 94488
# 94489
# 94490
# 94491
# 94492
# 94493
# 94494
# 94495
# 94496
# 94497
# 94498
# 94499
# 94500
# 94501
# 94502
# 94503
# 94504
# 94505
# 94506
# 94507
# 94508
# 94509
# 94510
# 94511
# 94512

# %%
len(review_adjs_list)
# Out:
# 94513

# %%
full_df["Review adjs"] = review_adjs_list

# %%
main_df
# Out:
#                 Property name                          Property address  \
# 0            Harbor 360 Hotel           1412 4th Ave., Seward, AK 99664
# 1            Harbor 360 Hotel           1412 4th Ave., Seward, AK 99664
# 2            Harbor 360 Hotel           1412 4th Ave., Seward, AK 99664
# 3            Harbor 360 Hotel           1412 4th Ave., Seward, AK 99664
# 4            Harbor 360 Hotel           1412 4th Ave., Seward, AK 99664
# ...                       ...                                       ...
# 111306  Anchorage Suite Lodge  441 E 15th Ave, Anchorage, AK 99501-5211
# 111307  Anchorage Suite Lodge  441 E 15th Ave, Anchorage, AK 99501-5211
# 111308  Anchorage Suite Lodge  441 E 15th Ave, Anchorage, AK 99501-5211
# 111309  Anchorage Suite Lodge  441 E 15th Ave, Anchorage, AK 99501-5211
# 111310  Anchorage Suite Lodge  441 E 15th Ave, Anchorage, AK 99501-5211
#
#                     Lat, long             Reviewer   Review date  \
# 0       60.119797,-149.439346               John M  October 2020
# 1       60.119797,-149.439346  Kenai Drift Anglers  October 2020
# 2       60.119797,-149.439346       TravelGirl2006  October 2020
# 3       60.119797,-149.439346             maduro44  October 2020
# 4       60.119797,-149.439346         rtfields2020  October 2020
# ...                       ...                  ...           ...
# 111306  61.207958,-149.875854      BigBubbaSpokane   August 2007
# 111307  61.207958,-149.875854              Angeles     July 2007
# 111308  61.207958,-149.875854              754Lynn     July 2005
# 111309  61.207958,-149.875854            Trek36846     June 2005
# 111310  61.207958,-149.875854           AKBeachBum    March 2004
#
#           Date of stay                                       Review title  \
# 0         October 2020           Awesome hotel doing all the right things
# 1         October 2020                               Great Local Get Away
# 2         October 2020                                 We love this hotel
# 3       September 2020                                                Bed
# 4       September 2020                                        Great place
# ...                ...                                                ...
# 111306     August 2007                                Horror in Anchorage
# 111307       July 2007                                   Do not stay here
# 111308       July 2005  Misleading-- Don't fall for this dump of a Hot...
# 111309        May 2005                                               Dump
# 111310             NaN                                       What a dump!
#
#                                               Full review  \
# 0       I stay at lots of hotels (including during Cov...
# 1       My girlfriend just wanted to get away from tow...
# 2       Have stayed here twice on our last two trips t...
# 3       Everything was really nice almost great if it ...
# 4       Terrific place to stay. Comfortable and clean,...
# ...                                                   ...
# 111306  This is the most disgusting, filthy, unsanitar...
# 111307  This hotel was booked for us as part of a grou...
# 111308  I booked a hotel on the road using a well know...
# 111309  This hotel was rated 3 star. What a joke! When...
# 111310  This hotel is the biggest dive in Anchorage. T...
#
#                                               Review link  \
# 0       https://www.tripadvisor.com/ShowUserReviews-g6...
# 1       https://www.tripadvisor.com/ShowUserReviews-g6...
# 2       https://www.tripadvisor.com/ShowUserReviews-g6...
# 3       https://www.tripadvisor.com/ShowUserReviews-g6...
# 4       https://www.tripadvisor.com/ShowUserReviews-g6...
# ...                                                   ...
# 111306  https://www.tripadvisor.com/ShowUserReviews-g6...
# 111307  https://www.tripadvisor.com/ShowUserReviews-g6...
# 111308  https://www.tripadvisor.com/ShowUserReviews-g6...
# 111309  https://www.tripadvisor.com/ShowUserReviews-g6...
# 111310  https://www.tripadvisor.com/ShowUserReviews-g6...
#
#                                      Spell-checked review  \
# 0       I stay at lots of hotels including during ovid...
# 1       My girlfriend just wanted to get away from tow...
# 2       Have stayed here twice on our last two trips t...
# 3       Everything was really nice almost great if it ...
# 4       Terrific place to stay. Comfortable and clean ...
# ...                                                   ...
# 111306  This is the most disgusting filthy unsanitary ...
# 111307  This hotel was booked for us as part of a grou...
# 111308  I booked a hotel on the road using a well know...
# 111309  This hotel was rated 3 star. What a joke! When...
# 111310  This hotel is the biggest dive in Anchorage Tw...
#
#                                            Cleaned review  Month of stay  \
# 0       stay lot hotel include ovid harbour right grea...           10.0
# 1       girlfriend want get away town enjoy great even...           10.0
# 2       stay twice last two trip seward view marina fa...           10.0
# 3       everything really nice almost great haunt bed ...            9.0
# 4       terrific place clean friendly staff excellent ...            9.0
# ...                                                   ...            ...
# 111306  disgust filthy unsanitary rundown hole ever en...            8.0
# 111307  hotel book us part group three couple suppose ...            7.0
# 111308  book hotel road use well know hotel website bo...            7.0
# 111309  hotel rate star joke try contact hotel phone d...            5.0
# 111310  hotel big dive anchorage two window break furn...            NaN
#
#         Year of stay  Vader +  Vader -  \
# 0             2020.0    0.250    0.000
# 1             2020.0    0.480    0.049
# 2             2020.0    0.480    0.000
# 3             2020.0    0.440    0.158
# 4             2020.0    0.401    0.000
# ...              ...      ...      ...
# 111306        2007.0    0.047    0.391
# 111307        2007.0    0.000    0.138
# 111308        2005.0    0.211    0.024
# 111309        2005.0    0.074    0.118
# 111310           NaN    0.000    0.268
#
#                                         Cleaned review v2  \
# 0       stay lot hotel include ovid harbour right grea...
# 1       girlfriend want away town enjoy great evening ...
# 2       stay twice trip seward view marina fantastic r...
# 3       really nice great haunt bed bed horrible mattr...
# 4       terrific place clean friendly staff excellent ...
# ...                                                   ...
# 111306  disgust filthy unsanitary rundown hole encount...
# 111307  hotel book group couple suppose stay night cou...
# 111308  book hotel road use know hotel website book ho...
# 111309  hotel rate star joke try contact hotel phone d...
# 111310  hotel big dive anchorage window break furnitur...
#
#                                              Review nouns
# 0       lot hotel harbour hotel price excellent locati...
# 1       girlfriend town evening restriction hotel brea...
# 2       trip seward view marina room spotless bathroom...
# 3           haunt bed bed horrible mattress help year bed
# 4       place staff breakfast sit balcony mountain har...
# ...                                                   ...
# 111306  disgust filthy rundown hole encounter daughter...
# 111307  hotel book group couple stay night couple plac...
# 111308  book hotel road use know hotel website book ho...
# 111309  hotel rate star joke contact hotel phone day a...
# 111310  hotel window break furniture hole nonsmoking r...
#
# [94513 rows x 17 columns]

# %%
len(full_df["Full review"].unique())
# Out:
# 93439

# %%
with open("newest_main_df.pickle", "wb") as to_write:
     pickle.dump(full_df, to_write)

# %%
full_df
# Out:
#                 Property name                          Property address  \
# 0            Harbor 360 Hotel           1412 4th Ave., Seward, AK 99664
# 1            Harbor 360 Hotel           1412 4th Ave., Seward, AK 99664
# 2            Harbor 360 Hotel           1412 4th Ave., Seward, AK 99664
# 3            Harbor 360 Hotel           1412 4th Ave., Seward, AK 99664
# 4            Harbor 360 Hotel           1412 4th Ave., Seward, AK 99664
# ...                       ...                                       ...
# 111306  Anchorage Suite Lodge  441 E 15th Ave, Anchorage, AK 99501-5211
# 111307  Anchorage Suite Lodge  441 E 15th Ave, Anchorage, AK 99501-5211
# 111308  Anchorage Suite Lodge  441 E 15th Ave, Anchorage, AK 99501-5211
# 111309  Anchorage Suite Lodge  441 E 15th Ave, Anchorage, AK 99501-5211
# 111310  Anchorage Suite Lodge  441 E 15th Ave, Anchorage, AK 99501-5211
#
#                     Lat, long             Reviewer   Review date  \
# 0       60.119797,-149.439346               John M  October 2020
# 1       60.119797,-149.439346  Kenai Drift Anglers  October 2020
# 2       60.119797,-149.439346       TravelGirl2006  October 2020
# 3       60.119797,-149.439346             maduro44  October 2020
# 4       60.119797,-149.439346         rtfields2020  October 2020
# ...                       ...                  ...           ...
# 111306  61.207958,-149.875854      BigBubbaSpokane   August 2007
# 111307  61.207958,-149.875854              Angeles     July 2007
# 111308  61.207958,-149.875854              754Lynn     July 2005
# 111309  61.207958,-149.875854            Trek36846     June 2005
# 111310  61.207958,-149.875854           AKBeachBum    March 2004
#
#           Date of stay                                       Review title  \
# 0         October 2020           Awesome hotel doing all the right things
# 1         October 2020                               Great Local Get Away
# 2         October 2020                                 We love this hotel
# 3       September 2020                                                Bed
# 4       September 2020                                        Great place
# ...                ...                                                ...
# 111306     August 2007                                Horror in Anchorage
# 111307       July 2007                                   Do not stay here
# 111308       July 2005  Misleading-- Don't fall for this dump of a Hot...
# 111309        May 2005                                               Dump
# 111310             NaN                                       What a dump!
#
#                                               Full review  \
# 0       I stay at lots of hotels (including during Cov...
# 1       My girlfriend just wanted to get away from tow...
# 2       Have stayed here twice on our last two trips t...
# 3       Everything was really nice almost great if it ...
# 4       Terrific place to stay. Comfortable and clean,...
# ...                                                   ...
# 111306  This is the most disgusting, filthy, unsanitar...
# 111307  This hotel was booked for us as part of a grou...
# 111308  I booked a hotel on the road using a well know...
# 111309  This hotel was rated 3 star. What a joke! When...
# 111310  This hotel is the biggest dive in Anchorage. T...
#
#                                               Review link  \
# 0       https://www.tripadvisor.com/ShowUserReviews-g6...
# 1       https://www.tripadvisor.com/ShowUserReviews-g6...
# 2       https://www.tripadvisor.com/ShowUserReviews-g6...
# 3       https://www.tripadvisor.com/ShowUserReviews-g6...
# 4       https://www.tripadvisor.com/ShowUserReviews-g6...
# ...                                                   ...
# 111306  https://www.tripadvisor.com/ShowUserReviews-g6...
# 111307  https://www.tripadvisor.com/ShowUserReviews-g6...
# 111308  https://www.tripadvisor.com/ShowUserReviews-g6...
# 111309  https://www.tripadvisor.com/ShowUserReviews-g6...
# 111310  https://www.tripadvisor.com/ShowUserReviews-g6...
#
#                                      Spell-checked review  \
# 0       I stay at lots of hotels including during ovid...
# 1       My girlfriend just wanted to get away from tow...
# 2       Have stayed here twice on our last two trips t...
# 3       Everything was really nice almost great if it ...
# 4       Terrific place to stay. Comfortable and clean ...
# ...                                                   ...
# 111306  This is the most disgusting filthy unsanitary ...
# 111307  This hotel was booked for us as part of a grou...
# 111308  I booked a hotel on the road using a well know...
# 111309  This hotel was rated 3 star. What a joke! When...
# 111310  This hotel is the biggest dive in Anchorage Tw...
#
#                                            Cleaned review  Month of stay  \
# 0       stay lot hotel include ovid harbour right grea...           10.0
# 1       girlfriend want get away town enjoy great even...           10.0
# 2       stay twice last two trip seward view marina fa...           10.0
# 3       everything really nice almost great haunt bed ...            9.0
# 4       terrific place clean friendly staff excellent ...            9.0
# ...                                                   ...            ...
# 111306  disgust filthy unsanitary rundown hole ever en...            8.0
# 111307  hotel book us part group three couple suppose ...            7.0
# 111308  book hotel road use well know hotel website bo...            7.0
# 111309  hotel rate star joke try contact hotel phone d...            5.0
# 111310  hotel big dive anchorage two window break furn...            NaN
#
#         Year of stay  Vader +  Vader -  \
# 0             2020.0    0.250    0.000
# 1             2020.0    0.480    0.049
# 2             2020.0    0.480    0.000
# 3             2020.0    0.440    0.158
# 4             2020.0    0.401    0.000
# ...              ...      ...      ...
# 111306        2007.0    0.047    0.391
# 111307        2007.0    0.000    0.138
# 111308        2005.0    0.211    0.024
# 111309        2005.0    0.074    0.118
# 111310           NaN    0.000    0.268
#
#                                         Cleaned review v2  Review length  \
# 0       stay lot hotel include ovid harbour right grea...             97
# 1       girlfriend want away town enjoy great evening ...             52
# 2       stay twice trip seward view marina fantastic r...            100
# 3       really nice great haunt bed bed horrible mattr...             54
# 4       terrific place clean friendly staff excellent ...             45
# ...                                                   ...            ...
# 111306  disgust filthy unsanitary rundown hole encount...             77
# 111307  hotel book group couple suppose stay night cou...            153
# 111308  book hotel road use know hotel website book ho...            149
# 111309  hotel rate star joke try contact hotel phone d...             64
# 111310  hotel big dive anchorage window break furnitur...             52
#
#                                              Review nouns  \
# 0       lot hotel harbour hotel price excellent locati...
# 1       girlfriend town evening restriction hotel brea...
# 2       trip seward view marina room spotless bathroom...
# 3           haunt bed bed horrible mattress help year bed
# 4       place staff breakfast sit balcony mountain har...
# ...                                                   ...
# 111306  disgust filthy rundown hole encounter daughter...
# 111307  hotel book group couple stay night couple plac...
# 111308  book hotel road use know hotel website book ho...
# 111309  hotel rate star joke contact hotel phone day a...
# 111310  hotel window break furniture hole nonsmoking r...
#
#                                               Review adjs
# 0              right great fair friendly clean reasonable
# 1                                       great covid great
# 2       fantastic large good adapt covid friendly grea...
# 3                                              nice great
# 4       terrific clean friendly excellent incredible r...
# ...                                                   ...
# 111306                 unsanitary late gross terrible bad
# 111307               awful second denali old large denali
# 111308  fancy decent clean affordable continental loca...
# 111309                                          light bad
# 111310                big dive anchorage dirty large real
#
# [94513 rows x 19 columns]
